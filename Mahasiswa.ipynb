# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Fatah/Projeckakhir_123190160_123190152/blob/main/Mahasiswa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !update-alternatives --config java <<< '2'
# Out:
# There are 2 choices for the alternative java (providing /usr/bin/java).
#
#   Selection    Path                                            Priority   Status
# ------------------------------------------------------------
# * 0            /usr/lib/jvm/java-11-openjdk-amd64/bin/java      1111      auto mode
#   1            /usr/lib/jvm/java-11-openjdk-amd64/bin/java      1111      manual mode
#   2            /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java   1081      manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode

# %%
2
# Out:
# 2

# %%
# !java -version
# Out:
# openjdk version "1.8.0_432"
# OpenJDK Runtime Environment (build 1.8.0_432-8u432-ga~us1-0ubuntu2~22.04-ga)
# OpenJDK 64-Bit Server VM (build 25.432-bga, mixed mode)

# %%
import os

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

os.environ["JRE_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64/jre"

os.environ["PATH"] += ":$JAVA_HOME/bin:$JRE_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin"

# %%
# !wget https://archive.apache.org/dist/hbase/2.2.3/hbase-2.2.3-bin.tar.gz
# Out:
# --2024-12-11 10:38:06--  https://archive.apache.org/dist/hbase/2.2.3/hbase-2.2.3-bin.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223539590 (213M) [application/x-gzip]
# Saving to: ‘hbase-2.2.3-bin.tar.gz’
#
# hbase-2.2.3-bin.tar 100%[===================>] 213.18M  41.8MB/s    in 6.0s
#
# 2024-12-11 10:38:13 (35.8 MB/s) - ‘hbase-2.2.3-bin.tar.gz’ saved [223539590/223539590]

# %%
# !tar xzvf hbase-2.2.3-bin.tar.gz
# Out:
# hbase-2.2.3/LICENSE.txt
# hbase-2.2.3/NOTICE.txt
# hbase-2.2.3/LEGAL
# hbase-2.2.3/CHANGES.md
# hbase-2.2.3/README.txt
# hbase-2.2.3/RELEASENOTES.md
# hbase-2.2.3/conf/
# hbase-2.2.3/conf/hadoop-metrics2-hbase.properties
# hbase-2.2.3/conf/log4j-hbtop.properties
# hbase-2.2.3/conf/hbase-env.sh
# hbase-2.2.3/conf/regionservers
# hbase-2.2.3/conf/hbase-policy.xml
# hbase-2.2.3/conf/hbase-site.xml
# hbase-2.2.3/conf/log4j.properties
# hbase-2.2.3/conf/hbase-env.cmd
# hbase-2.2.3/bin/
# hbase-2.2.3/bin/test/
# hbase-2.2.3/bin/replication/
# hbase-2.2.3/bin/hbase-daemons.sh
# hbase-2.2.3/bin/hbase-common.sh
# hbase-2.2.3/bin/start-hbase.sh
# hbase-2.2.3/bin/considerAsDead.sh
# hbase-2.2.3/bin/hbase-jruby
# hbase-2.2.3/bin/regionservers.sh
# hbase-2.2.3/bin/hirb.rb
# hbase-2.2.3/bin/shutdown_regionserver.rb
# hbase-2.2.3/bin/local-regionservers.sh
# hbase-2.2.3/bin/draining_servers.rb
# hbase-2.2.3/bin/test/process_based_cluster.sh
# hbase-2.2.3/bin/hbase
# hbase-2.2.3/bin/stop-hbase.sh
# ...

# %%
# !cd /content/hbase-2.2.3/bin/

# %%
# !/content/hbase-2.2.3/bin/start-hbase.sh
# Out:
# running master, logging to /content/hbase-2.2.3/bin/../logs/hbase--master-c438d4dc07a0.out

# %%
# !/content/hbase-2.2.3/bin/hbase shell
# Out:
# /bin/bash: line 1: /content/hbase-2.2.3/bin/hbase: No such file or directory

# %%
# !/content/hbase-2.2.3/bin/start-hbase.sh
# Out:
# /bin/bash: line 1: /content/hbase-2.2.3/bin/start-hbase.sh: No such file or directory

# %%
# !wget https://archive.apache.org/dist/hbase/2.2.3/hbase-2.2.3-bin.tar.gz
# Out:
# --2024-12-11 11:32:24--  https://archive.apache.org/dist/hbase/2.2.3/hbase-2.2.3-bin.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223539590 (213M) [application/x-gzip]
# Saving to: ‘hbase-2.2.3-bin.tar.gz’
#
# hbase-2.2.3-bin.tar 100%[===================>] 213.18M  13.0MB/s    in 17s
#
# 2024-12-11 11:32:41 (12.7 MB/s) - ‘hbase-2.2.3-bin.tar.gz’ saved [223539590/223539590]

# %%
# !tar xzvf hbase-2.2.3-bin.tar.gz
# Out:
# hbase-2.2.3/LICENSE.txt
# hbase-2.2.3/NOTICE.txt
# hbase-2.2.3/LEGAL
# hbase-2.2.3/CHANGES.md
# hbase-2.2.3/README.txt
# hbase-2.2.3/RELEASENOTES.md
# hbase-2.2.3/conf/
# hbase-2.2.3/conf/hadoop-metrics2-hbase.properties
# hbase-2.2.3/conf/log4j-hbtop.properties
# hbase-2.2.3/conf/hbase-env.sh
# hbase-2.2.3/conf/regionservers
# hbase-2.2.3/conf/hbase-policy.xml
# hbase-2.2.3/conf/hbase-site.xml
# hbase-2.2.3/conf/log4j.properties
# hbase-2.2.3/conf/hbase-env.cmd
# hbase-2.2.3/bin/
# hbase-2.2.3/bin/test/
# hbase-2.2.3/bin/replication/
# hbase-2.2.3/bin/hbase-daemons.sh
# hbase-2.2.3/bin/hbase-common.sh
# hbase-2.2.3/bin/start-hbase.sh
# hbase-2.2.3/bin/considerAsDead.sh
# hbase-2.2.3/bin/hbase-jruby
# hbase-2.2.3/bin/regionservers.sh
# hbase-2.2.3/bin/hirb.rb
# hbase-2.2.3/bin/shutdown_regionserver.rb
# hbase-2.2.3/bin/local-regionservers.sh
# hbase-2.2.3/bin/draining_servers.rb
# hbase-2.2.3/bin/test/process_based_cluster.sh
# hbase-2.2.3/bin/hbase
# hbase-2.2.3/bin/stop-hbase.sh
# ...

# %%
# !cd /content/hbase-2.2.3/bin/

# %%
# !/content/hbase-2.2.3/bin/start-hbase.sh
# Out:
# +======================================================================+
# |                    Error: JAVA_HOME is not set                       |
# +----------------------------------------------------------------------+
# | Please download the latest Sun JDK from the Sun Java web site        |
# |     > http://www.oracle.com/technetwork/java/javase/downloads        |
# |                                                                      |
# | HBase requires Java 1.8 or later.                                    |
# +======================================================================+

# %%
# !/content/hbase-2.2.3/bin/hbase shell
# Out:
# +======================================================================+
# |                    Error: JAVA_HOME is not set                       |
# +----------------------------------------------------------------------+
# | Please download the latest Sun JDK from the Sun Java web site        |
# |     > http://www.oracle.com/technetwork/java/javase/downloads        |
# |                                                                      |
# | HBase requires Java 1.8 or later.                                    |
# +======================================================================+

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !update-alternatives --config java <<< '2'
# Out:
# There are 2 choices for the alternative java (providing /usr/bin/java).
#
#   Selection    Path                                            Priority   Status
# ------------------------------------------------------------
# * 0            /usr/lib/jvm/java-11-openjdk-amd64/bin/java      1111      auto mode
#   1            /usr/lib/jvm/java-11-openjdk-amd64/bin/java      1111      manual mode
#   2            /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java   1081      manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode

# %%
# !update-alternatives --config jps <<< '2'
# Out:
# There are 2 choices for the alternative jps (providing /usr/bin/jps).
#
#   Selection    Path                                        Priority   Status
# ------------------------------------------------------------
# * 0            /usr/lib/jvm/java-11-openjdk-amd64/bin/jps   1111      auto mode
#   1            /usr/lib/jvm/java-11-openjdk-amd64/bin/jps   1111      manual mode
#   2            /usr/lib/jvm/java-8-openjdk-amd64/bin/jps    1081      manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jps to provide /usr/bin/jps (jps) in manual mode

# %%
# !java -version
# Out:
# openjdk version "1.8.0_432"
# OpenJDK Runtime Environment (build 1.8.0_432-8u432-ga~us1-0ubuntu2~22.04-ga)
# OpenJDK 64-Bit Server VM (build 25.432-bga, mixed mode)

# %%
import os

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

os.environ["JRE_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64/jre"

os.environ["PATH"] += ":$JAVA_HOME/bin:$JRE_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin"

# %%
# !cd /content/hbase-2.2.3/bin/

# %%
# !/content/hbase-2.2.3/bin/start-hbase.sh
# Out:
# running master, logging to /content/hbase-2.2.3/bin/../logs/hbase--master-6e7dc5d6e031.out

# %%
# !/content/hbase-2.2.3/bin/hbase shell
# Out:
# 2024-12-11 11:35:52,579 WARN  [main] util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# HBase Shell
# Use "help" to get list of supported commands.
# Use "exit" to quit this interactive shell.
# For Reference, please visit: http://hbase.apache.org/2.0/book.html#shell
# Version 2.2.3, r6a830d87542b766bd3dc4cfdee28655f62de3974, 2020年 01月 10日 星期五 18:27:51 CST
# Took 0.0039 seconds
# hbase(main):001:0> list
# list
# TABLE
# 0 row(s)
# Took 0.8248 seconds
# => []
# hbase(main):002:0> create 'Mahasiswa', 'biodata', 'kuliah', 'hima'
# create 'Mahasiswa', 'biodata', 'kuliah', 'hima'
# Created table Mahasiswa
# Took 0.8786 seconds
# => Hbase::Table - Mahasiswa
# hbase(main):003:0> put 'Mahasiswa', '1', 'biodata:nama', 'Aldi'
# put 'Mahasiswa', '1', 'biodata:nama', 'Aldi'
# Took 0.2598 seconds
# hbase(main):004:0> put 'Mahasiswa', '1', 'biodata:kota', 'Semarang'
# put 'Mahasiswa', '1', 'biodata:kota', 'Semarang'
# ...
